# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import geopandas as gpd
import pandas as pd
from shapely import wkt
from google.colab import drive

nychares_df = pd.read_csv('/content/drive/MyDrive/Informatics Final Project/Data_Sources/nycha_residential.csv')
pluto_df  = pd.read_csv('/content/drive/MyDrive/Informatics Final Project/Data_Sources/cleaned_PLUTO.csv')

nycha_gdf = gpd.GeoDataFrame(
    nychares_df,
    geometry=gpd.points_from_xy(nychares_df['longitude'], nychares_df['latitude']),
    crs='EPSG:2263'
)

pluto_gdf = gpd.GeoDataFrame(
    pluto_df,
    geometry=gpd.points_from_xy(pluto_df['longitude'], pluto_df['latitude']),
    crs='EPSG:2263'
)

# %%
pluto_gdf['bbl']  = pluto_gdf['bbl'].astype(str).str.strip()
nycha_gdf = nycha_gdf.rename(columns={'borough/block/lot_#': 'BBL'})

# %%
pluto_attrs = pluto_gdf.drop(columns='geometry')

# %%
pluto_attrs['bbl'] = pluto_attrs['bbl'].astype('int64')

combined_gdf = nycha_gdf.merge(
    pluto_attrs,
    left_on='BBL',
    right_on='bbl',
    how='left',
    suffixes=('_nycha', '_pluto')
)

combined_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2961 entries, 0 to 2960
# Data columns (total 93 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   development                        2961 non-null   object
#  1   tds_#                              2961 non-null   int64
#  2   building_#                         2961 non-null   object
#  3   stairhall#                         2961 non-null   int64
#  4   borough_nycha                      2961 non-null   object
#  5   house_#                            2961 non-null   object
#  6   street                             2961 non-null   object
#  7   address_nycha                      2961 non-null   object
#  8   city                               2961 non-null   object
#  9   state                              2961 non-null   object
#  10  zip_code                           2961 non-null   object
#  11  bin                                2961 non-null   int64
#  12  block                              2961 non-null   int64
#  13  lot                                2961 non-null   object
#  14  BBL                                2961 non-null   int64
#  15  census_tract_(2020)                2961 non-null   object
#  16  neighborhood_tabulation_area_code  2961 non-null   object
#  17  neighborhood_tabulation_area_name  2961 non-null   object
#  18  community_district                 2961 non-null   int64
#  19  city_council_district              2961 non-null   int64
#  20  state_assembly_district            2961 non-null   int64
#  21  state_senate_district              2961 non-null   int64
#  22  us_congressional_district          2961 non-null   int64
#  23  privately_managed                  85 non-null     object
#  24  latitude_nycha                     2961 non-null   float64
#  25  longitude_nycha                    2961 non-null   float64
#  26  geometry                           2961 non-null   geometry
#  27  borough_pluto                      2937 non-null   object
#  28  tax_block                          2937 non-null   float64
#  29  tax_lot                            2937 non-null   float64
#  30  census_tract_2010                  2937 non-null   float64
#  31  cb2010                             2937 non-null   float64
#  32  council_district                   2937 non-null   float64
#  33  postcode                           2937 non-null   float64
#  34  policeprct                         2937 non-null   float64
#  35  healtharea                         2937 non-null   float64
#  36  address_pluto                      2937 non-null   object
#  37  zonedist1                          2937 non-null   object
#  38  zonedist2                          151 non-null    object
#  39  zonedist3                          2 non-null      object
#  40  zonedist4                          0 non-null      object
#  41  ltdheight                          0 non-null      float64
#  42  bldgclass                          2937 non-null   object
#  43  landuse                            2937 non-null   float64
#  44  easements                          2937 non-null   float64
#  45  ownertype                          2937 non-null   object
#  46  ownername                          2937 non-null   object
#  47  lotarea                            2937 non-null   object
#  48  bldgarea                           2937 non-null   object
#  49  resarea                            2913 non-null   object
#  50  garagearea                         2913 non-null   object
#  51  strgearea                          2913 non-null   object
#  52  otherarea                          2913 non-null   object
#  53  areasource                         2937 non-null   float64
#  54  numbldgs                           2937 non-null   float64
#  55  numfloors                          2937 non-null   float64
#  56  unitsres                           2937 non-null   object
#  57  unitstotal                         2937 non-null   object
#  58  lotfront                           2937 non-null   object
#  59  lotdepth                           2937 non-null   object
#  60  bldgfront                          2937 non-null   float64
#  61  bldgdepth                          2937 non-null   float64
#  62  proxcode                           2937 non-null   float64
#  63  irrlotcode                         2937 non-null   object
#  64  lottype                            2937 non-null   float64
#  65  assessland                         2937 non-null   float64
#  66  assesstot                          2937 non-null   float64
#  67  yearbuilt                          2937 non-null   float64
#  68  yearalter1                         2937 non-null   object
#  69  yearalter2                         2937 non-null   object
#  70  histdist                           40 non-null     object
#  71  landmark                           8 non-null      object
#  72  builtfar                           2937 non-null   float64
#  73  residfar                           2937 non-null   float64
#  74  borocode                           2937 non-null   float64
#  75  bbl                                2937 non-null   float64
#  76  tract2010                          2937 non-null   float64
#  77  xcoord                             2937 non-null   float64
#  78  ycoord                             2937 non-null   float64
#  79  latitude_pluto                     2937 non-null   float64
#  80  longitude_pluto                    2937 non-null   float64
#  81  zonemap                            2937 non-null   object
#  82  zmcode                             303 non-null    object
#  83  appbbl                             283 non-null    float64
#  84  appdate                            283 non-null    object
#  85  plutomapid                         2937 non-null   float64
#  86  dcpedited                          227 non-null    object
#  87  notes                              0 non-null      float64
#  88  bct2020                            2937 non-null   float64
#  89  bctcb2020                          2937 non-null   float64
#  90  yearbuilt_dt                       2937 non-null   object
#  91  yearalter1_dt                      903 non-null    object
#  92  yearalter2_dt                      30 non-null     object
# dtypes: float64(37), geometry(1), int64(10), object(45)
# memory usage: 2.1+ MB

# %%
print(f"NYCHA rows:    {len(nycha_gdf)}")
print(f"Combined rows: {len(combined_gdf)}")
# Out:
# NYCHA rows:    2961
# Combined rows: 2961

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 10))

# Plot PLUTO lot points as a light background reference
pluto_gdf.plot(ax=ax, color='lightgrey', markersize=1, label='PLUTO lots')

# Plot NYCHA points on top
combined_gdf.plot(ax=ax, color='red', markersize=5, label='NYCHA buildings')

ax.set_title('NYCHA Buildings overlaid on PLUTO Data')
ax.legend()
plt.show()

# %%
# Check a sample of rows to confirm PLUTO columns populated correctly
combined_gdf[['BBL', 'bbl', 'development', 'landuse', 'yearbuilt']].sample(10)
# Out:
#              BBL           bbl                    development  landuse  \
# 238   3081580001  3.081580e+09                      BREUKELEN      3.0
# 147   3030810060  3.030810e+09             BORINQUEN PLAZA II      3.0
# 660   3042920061  3.042920e+09                  CYPRESS HILLS      3.0
# 2848  3020410001  3.020410e+09                        WHITMAN      4.0
# 2550  3021750060  3.021750e+09     TAYLOR STREET-WYTHE AVENUE      3.0
# 1601  2022630019  2.022630e+09                     MILL BROOK      3.0
# 738   2029890001  2.029890e+09  EAST 173RD STREET-VYSE AVENUE      2.0
# 2366  2037230001  2.037230e+09               SOTOMAYOR HOUSES      3.0
# 153   2037150025  2.037150e+09           BOYNTON AVENUE REHAB      2.0
# 53    4004900101  4.004900e+09                        ASTORIA      3.0
#
#       yearbuilt
# 238      1950.0
# 147      1972.0
# 660      1954.0
# 2848     1939.0
# 2550     1974.0
# 1601     1956.0
# 738      1986.0
# 2366     1953.0
# 153      1928.0
# 53       1950.0

# %%
import folium
from folium.plugins import MarkerCluster

# Center map on NYC
m = folium.Map(location=[40.7128, -74.0060], zoom_start=11)

# Add NYCHA points as clustered markers
marker_cluster = MarkerCluster().add_to(m)

for _, row in combined_gdf.iterrows():
    folium.Marker(
        location=[row.geometry.y, row.geometry.x],
        popup=f"BBL: {row['BBL']}<br>Development: {row.get('development', 'N/A')}",
    ).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_860dbec98ca6ada7e013aeaa936463df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_860dbec98ca6ada7e013aeaa936463df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_860dbec98ca6ada7e013aeaa936463df = L.map(
#                 &quot;map_860dbec98ca6ada7e013aeaa936463df&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a358f5b368bdf95fea9ddd2e246e548a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a358f5b368bdf95fea9ddd2e246e548a.addTo(map_860dbec98ca6ada7e013aeaa936463df);
#
#
#             var marker_cluster_a3933cde0e12e1bf7ea9c29c9dd60161 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_ad0eb0b129b1e675ff38d65467b7aa50 = L.marker(
#                 [40.829928, -73.907535],
#                 {
# }
#             ).addTo(marker_cluster_a3933cde0e12e1bf7ea9c29c9dd60161);
#
#
#         var popup_d1e9b0542f0a0c2c8752fb2221abeaba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1241c9c213fd6b8815e9ae8882cea0ed = $(`&lt;div id=&quot;html_1241c9c213fd6b8815e9ae8882cea0ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BBL: 2023720001&lt;br&gt;Development: 1162-1176 WASHINGTON AVENUE&lt;/div&gt;`)[0];
#                 popup_d1e9b0542f0a0c2c8752fb2221abeaba.setContent(html_1241c9c213fd6b8815e9ae8882cea0ed);
#
#
#
#         marker_ad0eb0b129b1e675ff38d65467b7aa50.bindPopup(popup_d1e9b0542f0a0c2c8752fb2221abeaba)
#         ;
#
#
#
#
#             var marker_1f286a7de56642eeafc46c576d240c1c = L.marker(
#                 [40.82585, -73.880943],
#                 {
# }
#             ).addTo(marker_cluster_a3933cde0e12e1bf7ea9c29c9dd60161);
#
#
#         var popup_378cb6fd34fa31666095fcd039152bad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3ffb5b0daeb3d6aebb01e49f3dfd2c4 = $(`&lt;div id=&quot;html_c3ffb5b0daeb3d6aebb01e49f3dfd2c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BBL: 2037370001&lt;br&gt;Development: 1471 WATSON AVENUE&lt;/div&gt;`)[0];
#                 popup_378cb6fd34fa31666095fcd039152bad.setContent(html_c3ffb5b0daeb3d6aebb01e49f3dfd2c4);
#
#
#
#         marker_1f286a7de56642eeafc46c576d240c1c.bindPopup(popup_378cb6fd34fa31666095fcd039152bad)
#         ;
#
#
#
#
#             var marker_28bd2a9618d734db174a16cd01bc3f7b = L.marker(
#                 [40.785976, -73.975263],
#                 {
# }
#             ).addTo(marker_cluster_a3933cde0e12e1bf7ea9c29c9dd60161);
#
#
#         var popup_56f98c3385138e1fa2e1652d0f22bfce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ecf5d2e9b40fcd30234323d5dae7bda = $(`&lt;div id=&quot;html_0ecf5d2e9b40fcd30234323d5dae7bda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BBL: 1012140055&lt;br&gt;Development: 154 WEST 84TH STREET&lt;/div&gt;`)[0];
#                 popup_56f98c3385138e1fa2e1652d0f22bfce.setContent(html_0ecf5d2e9b40fcd30234323d5dae7bda);
#
#
#
#         marker_28bd2a9618d734db174a16cd01bc3f7b.bindPopup(popup_56f98c3385138e1fa2e1652d0f22bfce)
#         ;
#
#
#
#
#             var marker_6fa1bf7b2d40f6a9a861599ad398b257 = L.marker(
#                 [40.695921, -73.939715],
#                 {
# }
#             ).addTo(marker_cluster_a3933cde0e12e1bf7ea9c29c9dd60161);
#
#
#         var popup_3cd5f2b4e51cd68b6f4fb8c9b5365fdb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37243fbcd5eded5e0fa1a4228ddae71d = $(`&lt;div id=&quot;html_37243fbcd5eded5e0fa1a4228ddae71d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BBL: 3015850001&lt;br&gt;Development: 303 VERNON AVENUE&lt;/div&gt;`)[0];
#                 popup_3cd5f2b4e51cd68b6f4fb8c9b5365fdb.setContent(html_37243fbcd5eded5e0fa1a4228ddae71d);

# %%
combined_gdf.to_csv('/content/drive/MyDrive/Informatics Final Project/Data_Sources/combined_nychares_pluto.csv', index = False)

# %%
# Load electric consumption and cost data

consumption_cost_df = pd.read_csv('/content/drive/MyDrive/Informatics Final Project/Data_Sources/raw_data/energy data/Electric_Consumption_And_Cost_(2010_-_Sep_2025)_20260314.csv')


# Clean data

consumption_cost_df_cleaned = consumption_cost_df.copy()

consumption_cost_df_cleaned.columns= (consumption_cost_df.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
)

# Drop columns

consumption_cost_df_cleaned.drop(columns=['edp', 'account_name', 'location', 'meter_amr',
       'meter_scope', 'umis_bill_id', 'amp_#', 'rc_code', 'estimated','rate_class','bill_analyzed'])
# Out:
#                   development_name   borough  tds_# funding_source  \
# 0                   SHEEPSHEAD BAY  BROOKLYN   36.0        FEDERAL
# 1                   SHEEPSHEAD BAY  BROOKLYN   36.0        FEDERAL
# 2                   SHEEPSHEAD BAY  BROOKLYN   36.0        FEDERAL
# 3                   SHEEPSHEAD BAY  BROOKLYN   36.0        FEDERAL
# 4                   SHEEPSHEAD BAY  BROOKLYN   36.0        FEDERAL
# ...                            ...       ...    ...            ...
# 553661  TAYLOR STREET-WYTHE AVENUE  BROOKLYN  234.0        FEDERAL
# 553662                     REDFERN    QUEENS   55.0        FEDERAL
# 553663                       MARCY  BROOKLYN   21.0        FEDERAL
# 553664                       MARCY  BROOKLYN   21.0        FEDERAL
# 553665                       MARCY  BROOKLYN   21.0        FEDERAL
#
#                         vendor_name revenue_month service_start_date  \
# 0          NEW YORK POWER AUTHORITY       2025-09         08/21/2025
# 1          NEW YORK POWER AUTHORITY       2025-09         08/21/2025
# 2          NEW YORK POWER AUTHORITY       2025-09         08/21/2025
# 3          NEW YORK POWER AUTHORITY       2025-09         08/21/2025
# 4          NEW YORK POWER AUTHORITY       2025-09         08/21/2025
# ...                             ...           ...                ...
# 553661     NEW YORK POWER AUTHORITY       2010-01         12/24/2009
# 553662  Long Island Power Authority       2010-01         12/23/2009
# 553663     NEW YORK POWER AUTHORITY       2010-01         12/24/2009
# 553664     NEW YORK POWER AUTHORITY       2010-01         12/24/2009
# 553665     NEW YORK POWER AUTHORITY       2010-01         12/24/2009
#
#        service_end_date  #_days meter_number current_charges  \
# 0            09/22/2025    32.0     12787077       $5,106.45
# 1            09/22/2025    32.0     12786820       $5,581.02
# 2            09/22/2025    32.0      4499227       $4,791.96
# 3            09/22/2025    32.0     12787144       $6,225.81
# 4            09/22/2025    32.0     12787064       $5,254.21
# ...                 ...     ...          ...             ...
# 553661       01/26/2010    33.0      6815000      $16,688.82
# 553662       01/26/2010    34.0       300987      $53,651.93
# 553663       01/26/2010    33.0      1009854        $1,507.9
# 553664       01/26/2010    33.0      1833954        $1,507.9
# 553665       01/26/2010    33.0      1833959       $1,107.31
#
#        consumption_(kwh) kwh_charges consumption_(kw) kw_charges other_charges
# 0                 33,001   $1,523.76                0         $0     $3,582.69
# 1                 36,068   $1,665.38                0         $0     $3,915.64
# 2                 30,969   $1,429.94                0         $0     $3,362.02
# 3                 40,235   $1,857.78                0         $0     $4,368.03
# 4                 33,956   $1,567.86                0         $0     $3,686.35
# ...                  ...         ...              ...        ...           ...
# 553661           130,000    $7,456.8              248     $3,224     $6,008.02
# 553662           353,000   $12,060.3                0  $3,240.74    $38,350.89
# 553663                 0          $0            75.17    $977.21       $530.69
# 553664                 0          $0            75.17    $977.21       $530.69
# 553665                 0          $0             55.2     $717.6       $389.71
#
# [553666 rows x 16 columns]

# %%
consumption_cost_df_cleaned['consumption_(kwh)'] = (
    consumption_cost_df_cleaned['consumption_(kwh)']
    .str.replace(',', '')
    .astype(float)
)

consumption_cost_df_cleaned = consumption_cost_df_cleaned.dropna(subset=['tds_#'])

consumption_cost_df_cleaned['tds_#'] = (
    consumption_cost_df_cleaned['tds_#']
    .astype(float)
    .astype(int)
    .astype(str)
)

# %%
consumption_cost_df_cleaned['tds_#'].value_counts().head(20)
# Out:
# tds_#
# 57     10837
# 2      10395
# 48     10239
# 56      9449
# 63      9278
# 67      9026
# 21      8573
# 53      8476
# 83      8469
# 16      8284
# 39      7882
# 377     7330
# 4       7259
# 26      7192
# 74      7124
# 61      7069
# 92      6613
# 6       6558
# 33      6533
# 44      6267
# Name: count, dtype: int64

# %%
# Clean tds_# in consumption_cost_df_cleaned first
consumption_cost_df_cleaned['tds_#'] = (
    consumption_cost_df_cleaned['tds_#']
    .astype(str)
    .str.replace(',', '')
    .str.strip()
    .str.replace('\.0$', '', regex=True)  # remove trailing .0
)

print(consumption_cost_df_cleaned['tds_#'].head(10).tolist())  # verify before aggregating

# Aggregate columns

consumption_agg = (
    consumption_cost_df_cleaned
    .groupby('tds_#')
    .agg({
        'consumption_(kwh)': 'sum',
        'current_charges': 'sum',
        'borough': 'first'
    })
    .reset_index()
)

# Merge

combined_gdf['tds_#'] = combined_gdf['tds_#'].astype(str).str.strip()
consumption_agg['tds_#'] = consumption_agg['tds_#'].astype(str).str.strip()

final_gdf = combined_gdf.merge(consumption_agg, on='tds_#', how='left')
print(final_gdf['consumption_(kwh)'].isna().sum())
print(final_gdf[['development', 'tds_#', 'consumption_(kwh)']].head(10))
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\.'
# <>:9: SyntaxWarning: invalid escape sequence '\.'
# /tmp/ipykernel_4674/4263629564.py:9: SyntaxWarning: invalid escape sequence '\.'
#   .str.replace('\.0$', '', regex=True)  # remove trailing .0
# ['36', '36', '36', '36', '36', '36', '36', '36', '36', '36']
# 49
#                    development tds_#  consumption_(kwh)
# 0  1162-1176 WASHINGTON AVENUE   233          8712982.0
# 1           1471 WATSON AVENUE   214          9580048.0
# 2         154 WEST 84TH STREET   359          2191151.0
# 3            303 VERNON AVENUE   156         24744232.0
# 4              45 ALLEN STREET   265         13181295.0
# 5         830 AMSTERDAM AVENUE   150         19069795.0
# 6                        ADAMS   118         97995861.0
# 7                        ADAMS   118         97995861.0
# 8                        ADAMS   118         97995861.0
# 9                        ADAMS   118         97995861.0

# %%
consumption_cost_df_cleaned.columns.tolist()
# Out:
# ['development_name',
#  'borough',
#  'account_name',
#  'location',
#  'meter_amr',
#  'meter_scope',
#  'tds_#',
#  'edp',
#  'rc_code',
#  'funding_source',
#  'amp_#',
#  'vendor_name',
#  'umis_bill_id',
#  'revenue_month',
#  'service_start_date',
#  'service_end_date',
#  '#_days',
#  'meter_number',
#  'estimated',
#  'current_charges',
#  'rate_class',
#  'bill_analyzed',
#  'consumption_(kwh)',
#  'kwh_charges',
#  'consumption_(kw)',
#  'kw_charges',
#  'other_charges']

# %%
# Generate top 10 developments by aggregate consumption

final_gdf.groupby('development')['consumption_(kwh)'].sum().sort_values(ascending=False).head(10)
# Out:
# development
# POMONOK                 2.210931e+10
# BREUKELEN               1.470409e+10
# MARCY                   1.077808e+10
# RAVENSWOOD              9.241181e+09
# THROGGS NECK            8.036913e+09
# CLASON POINT GARDENS    7.614483e+09
# BARUCH                  7.306637e+09
# RED HOOK EAST           7.017741e+09
# WOODSIDE                6.903743e+09
# INGERSOLL               6.194968e+09
# Name: consumption_(kwh), dtype: float64

# %%
# Top 20 developments by total energy consumption

import matplotlib.pyplot as plt

top20_total = (
    final_gdf.groupby('development')['consumption_(kwh)']
    .sum()
    .sort_values(ascending=True)
    .tail(20)
)

fig, ax = plt.subplots(figsize=(10, 8))
top20_total.plot(kind='barh', ax=ax, color='steelblue')
ax.set_xlabel('Total Consumption (KWH)')
ax.set_title('Top 20 NYCHA Developments by Total Energy Consumption')
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:,.0f}'))
plt.tight_layout()
plt.show()

# %%
# Top 20 developments by energy consumption per unit

final_gdf['consumption_(kwh)'] = pd.to_numeric(final_gdf['consumption_(kwh)'], errors='coerce')
final_gdf['unitsres'] = pd.to_numeric(final_gdf['unitsres'], errors='coerce')

final_gdf['consumption_per_unit'] = final_gdf['consumption_(kwh)'] / final_gdf['unitsres']

top20_perunit = (
    final_gdf.dropna(subset=['development', 'consumption_per_unit'])
    .groupby('development')['consumption_per_unit']
    .mean()
    .sort_values(ascending=True)
    .tail(20)
)


fig, ax = plt.subplots(figsize=(10, 8))
top20_perunit.plot(kind='barh', ax=ax, color='darkorange')
ax.set_xlabel('Consumption per Residential Unit (KWH)')
ax.set_title('Top 20 NYCHA Developments by Energy Consumption Per Unit')
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:,.0f}'))
plt.tight_layout()
plt.show()

# %%
# Energy consumption vs building age

fig, ax = plt.subplots(figsize=(10, 6))

scatter_df = final_gdf.dropna(subset=['yearbuilt', 'consumption_(kwh)'])
scatter_df = scatter_df[scatter_df['yearbuilt'] > 0]  # drop placeholder 0s

ax.scatter(scatter_df['yearbuilt'], scatter_df['consumption_(kwh)'],
           alpha=0.5, color='steelblue', edgecolors='white', linewidth=0.3)

ax.set_xlabel('Year Built')
ax.set_ylabel('Total Consumption (KWH)')
ax.set_title('Energy Consumption vs. Building Age (NYCHA)')
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:,.0f}'))
plt.tight_layout()
plt.show()

# %%
# Energy consumption per unit vs building age

fig, ax = plt.subplots(figsize=(10, 6))

scatter_df2 = final_gdf.dropna(subset=['yearbuilt', 'consumption_per_unit'])
scatter_df2 = scatter_df2[scatter_df2['yearbuilt'] > 0]  # drop placeholder 0s

ax.scatter(scatter_df2['yearbuilt'], scatter_df2['consumption_per_unit'],
           alpha=0.5, color='darkorange', edgecolors='white', linewidth=0.3)

ax.set_xlabel('Year Built')
ax.set_ylabel('Consumption (KWH) Per Unit')
ax.set_title('Energy Consumption Per Unit vs. Building Age (NYCHA)')
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:,.0f}'))
plt.tight_layout()
plt.show()

# %%
# Energy costs per unit by borough

consumption_cost_df_cleaned['revenue_month'] = pd.to_datetime(consumption_cost_df_cleaned['revenue_month'])
consumption_2024 = consumption_cost_df_cleaned[
    consumption_cost_df_cleaned['revenue_month'].dt.year == 2024
].copy()

# Clean and aggregate
consumption_2024['current_charges'] = (
    consumption_2024['current_charges']
    .astype(str)
    .str.replace('[$,]', '', regex=True)
    .str.strip()
)
consumption_2024['current_charges'] = pd.to_numeric(consumption_2024['current_charges'], errors='coerce')

consumption_agg_2024 = (
    consumption_2024
    .groupby('tds_#')
    .agg({
        'consumption_(kwh)': 'sum',
        'current_charges': 'sum',
        'borough': 'first'
    })
    .reset_index()
)

consumption_agg_2024['tds_#'] = consumption_agg_2024['tds_#'].astype(str).str.strip()
combined_gdf['tds_#'] = combined_gdf['tds_#'].astype(str).str.strip()

final_gdf_2024 = combined_gdf.merge(consumption_agg_2024, on='tds_#', how='left')
final_gdf_2024['current_charges'] = pd.to_numeric(final_gdf_2024['current_charges'], errors='coerce')
final_gdf_2024['unitsres'] = pd.to_numeric(final_gdf_2024['unitsres'], errors='coerce')

# Calculate cost per unit
cost_per_unit_df = final_gdf_2024.dropna(subset=['current_charges', 'unitsres', 'borough']).copy()
cost_per_unit_df = cost_per_unit_df[cost_per_unit_df['unitsres'] > 0]
cost_per_unit_df['cost_per_unit'] = cost_per_unit_df['current_charges'] / cost_per_unit_df['unitsres']

# Build borough groups
borough_groups = {
    b: cost_per_unit_df[cost_per_unit_df['borough'] == b]['cost_per_unit'].dropna()
    for b in cost_per_unit_df['borough'].unique()
}
borough_groups = {k: v for k, v in borough_groups.items() if len(v) > 0}

# Plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.boxplot(borough_groups.values(), labels=borough_groups.keys(), patch_artist=True,
           boxprops=dict(facecolor='steelblue', alpha=0.6))
ax.set_xlabel('Borough')
ax.set_ylabel('Energy Cost per Residential Unit ($)')
ax.set_title('Energy Cost per Unit by Borough — NYCHA (2024)')
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'${x:,.0f}'))
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_4674/863513121.py:49: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(borough_groups.values(), labels=borough_groups.keys(), patch_artist=True,

# %%
final_gdf.to_csv('combined.csv', index=False)
